# %%
import setuptools_scm as st

# %%
??st.format_version

# %%
lambda x : '.'.join(x.split('.')[:3])
# Out:
# <function __main__.<lambda>>

# %%
st.get_version()
# Out:
# '1.3.1.dev0+g405e973.d20170515'

# %%
import subprocess

# %%
subprocess.check_output(["git", "describe"])
# Out:
# b'v1.3.0-1-g86ae00e\n'

# %%
"{ver}".format(ver=version_git)
# Out:
# "b'v1.3.0-1-g86ae00e'"

# %%
import os

# %%
version_py = os.path.join('.', 'version.py')

try:
    version_git = subprocess.check_output(["git", "describe"]).rstrip()
except:
    with open(version_py, 'r') as fh:
        version_git = open(version_py).read().strip().split('=')[-1].replace('"','')

# %%
bytes.decode(version_git)
# Out:
# 'v1.3.0-1-g86ae00e'

# %%
version_msg = "# Do not edit this file, pipeline versioning is governed by git tags"
with open(version_py, 'w') as fh:
    fh.write(version_msg + os.linesep + "__version__=" + version_git)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-9416d401af53> in <module>()
#       1 version_msg = "# Do not edit this file, pipeline versioning is governed by git tags"
#       2 with open(version_py, 'w') as fh:
# ----> 3     fh.write(version_msg + os.linesep + "__version__=" + version_git)
#
# TypeError: Can't convert 'bytes' object to str implicitly

# %%
# setup(name="yourpythonpackage",
version="{ver}".format(ver=version_git),

# %%
bytes.decode(subprocess.check_output(["git", "describe"]))
# Out:
# 'v1.3.0-1-g86ae00e\n'

# %%
# Fetch version from git tags, and write to version.py.
# Also, when git is not available (PyPi package), use stored version.py.
version_py = os.path.join('.', 'version.py')

# try:
#     version_git = bytes.decode(subprocess.check_output(["git", "describe"]).rstrip())[1:]
# except:
    with open(version_py, 'r') as fh:
        version_git = fh.read().strip().split('=')[-1].replace('"','')
    with open(version_py, 'r') as fh:
        version_git = fh.read().strip().split('=')[-1].replace('"','')

version_msg = "# Do not edit this file, pipeline versioning is governed by git tags"
with open(version_py, 'w') as fh:
#     fh.write(version_msg + os.linesep + "__version__=" + version_git)
    fh.write(version_msg + os.linesep + "__version__=" + version_git)

# %%
test = bytes.decode(subprocess.check_output(["git", "describe"]).rstrip())

# %%
test[1:]
# Out:
# '1.3.0'

# %%
with open(version_py, 'r') as fh:
    version_git = fh.read().strip().split('=')[-1]
    print(version_git)
# Out:
# 1.3.0

# %%
version_git
# Out:
# '1.3.0'
