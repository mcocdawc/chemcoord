# %% [markdown]
# Welcome to the tutorial for ChemCoord (http://chemcoord.readthedocs.org/en/v1.0.0/).
#
# It is recommended to use a molecule viewer like ``MOLCAS gv``, ``avogadro``, ``VMD`` or ``molpy`` to look on the created files.

# %%
import chemcoord as cc
import pandas as pd
import math as m
import numpy as np
import urllib
write_molden = cc.Cartesian.write_molden

# %% [markdown]
# We need to download four example xyz-files.

# %%
download_dict = {'MIL53_middle.xyz' : 'http://tny.im/3-L',
                'MIL53_small.xyz' : 'http://tny.im/3-M',
                 'nasty_linear.xyz' : 'http://tny.im/3-O',
                 'nasty_cube.xyz' : 'http://tny.im/3-N'
                }
for file, url in download_dict.items():
    urllib.request.urlretrieve(url, file)

# %% [markdown]
# # Basic stuff

# %% [markdown]
# Import an xyz-file with the read method

# %%
small = cc.Cartesian.read_xyz('MIL53_small.xyz')
middle = cc.Cartesian.read_xyz('MIL53_middle.xyz')

# %% [markdown]
# Look at it.

# %%
small
# Out:
#    atom         x         y         z
# 1     O  1.231322 -4.500872  0.412999
# 2     C  1.837959 -3.409845  0.790434
# 3     O  0.000000 -3.409845 -1.899798
# 4     O -1.231322 -4.500872  0.412999
# 5     C -1.837959 -3.409845  0.790434
# 6    Cr  0.000000 -1.705085 -0.950310
# 7     O  0.000000  0.000000  0.000000
# 8     O  1.508702 -1.111842 -2.033639
# 9     O  1.231322 -2.318819  0.412999
# 10    C  2.097946  0.000000 -2.374492
# 11   Cr  0.000000  1.705085 -0.950310
# 12    O  1.508702  1.111842 -2.033639
# 13    O  1.231322  2.318819  0.412999
# 14    C  1.837959  3.409845  0.790434
# 15    O -1.231322 -2.318819  0.412999
# 16    O -1.508702 -1.111842 -2.033639
# 17    C -2.097946  0.000000 -2.374492
# 18    O  0.000000  3.409845 -1.899798
# 19    O -1.231322  2.318819  0.412999
# 20    O -1.508702  1.111842 -2.033639
# 21    C -1.837959  3.409845  0.790434
# 22    O  1.231322  4.500872  0.412999
# 23    O -1.231322  4.500872  0.412999
# 24    C  3.362421  0.000000 -3.105936
# 25    H  3.444053 -0.884279 -3.742741
# 26    H  4.210678  0.000000 -2.417446
# 27    C  3.078276 -3.409845  1.562132
# 28    H  2.948217 -2.695167  2.440298
# 29    H  3.399300 -4.313795  1.890694
# 30    H  3.881149 -2.895298  0.951982
# 31    C -3.078276 -3.409845  1.562132
# 32    C -3.362421  0.000000 -3.105936
# 33    C  3.078276  3.409845  1.562132
# 34    C -3.078276  3.409845  1.562132
# 35    H -3.444053  0.884279 -3.742741
# 36    H  3.444053  0.884279 -3.742741
# 37    H -3.444053 -0.884279 -3.742741
# 38    H -4.210678  0.000000 -2.417446
# 39    H -2.948217  2.695167  2.440298
# 40    H  2.948217  2.695167  2.440298
# 41    H -2.948217 -2.695167  2.440298
# 42    H -3.399300  4.313795  1.890694
# 43    H  3.399300  4.313795  1.890694
# 44    H -3.399300 -4.313795  1.890694
# 45    H -3.881149  2.895298  0.951982
# 46    H  3.881149  2.895298  0.951982
# 47    H -3.881149 -2.895298  0.951982
# 48    H  0.000000  3.543451 -2.779712
# 49    H  1.769272  5.235369  0.747699
# 50    H -1.769272  5.235369  0.747699
# 51    H  1.769272 -5.235369  0.747699
# 52    H -1.769272 -5.235369  0.747699
# 53    H  0.000000  0.000000  0.890000
# 54    H  0.000000  4.228280 -1.550135
# 55    H  0.000000 -3.543451 -2.779712
# 56    H  0.000000 -4.228280 -1.550135

# %% [markdown]
# Add additional data

# %%
small.add_data(['mass', 'jmol_color'])
# Out:
#    atom         x         y         z      mass jmol_color
# 1     O  1.231322 -4.500872  0.412999  15.99940    #ff0d0d
# 2     C  1.837959 -3.409845  0.790434  12.01100    #909090
# 3     O  0.000000 -3.409845 -1.899798  15.99940    #ff0d0d
# 4     O -1.231322 -4.500872  0.412999  15.99940    #ff0d0d
# 5     C -1.837959 -3.409845  0.790434  12.01100    #909090
# 6    Cr  0.000000 -1.705085 -0.950310  51.99610    #8a99c7
# 7     O  0.000000  0.000000  0.000000  15.99940    #ff0d0d
# 8     O  1.508702 -1.111842 -2.033639  15.99940    #ff0d0d
# 9     O  1.231322 -2.318819  0.412999  15.99940    #ff0d0d
# 10    C  2.097946  0.000000 -2.374492  12.01100    #909090
# 11   Cr  0.000000  1.705085 -0.950310  51.99610    #8a99c7
# 12    O  1.508702  1.111842 -2.033639  15.99940    #ff0d0d
# 13    O  1.231322  2.318819  0.412999  15.99940    #ff0d0d
# 14    C  1.837959  3.409845  0.790434  12.01100    #909090
# 15    O -1.231322 -2.318819  0.412999  15.99940    #ff0d0d
# 16    O -1.508702 -1.111842 -2.033639  15.99940    #ff0d0d
# 17    C -2.097946  0.000000 -2.374492  12.01100    #909090
# 18    O  0.000000  3.409845 -1.899798  15.99940    #ff0d0d
# 19    O -1.231322  2.318819  0.412999  15.99940    #ff0d0d
# 20    O -1.508702  1.111842 -2.033639  15.99940    #ff0d0d
# 21    C -1.837959  3.409845  0.790434  12.01100    #909090
# 22    O  1.231322  4.500872  0.412999  15.99940    #ff0d0d
# 23    O -1.231322  4.500872  0.412999  15.99940    #ff0d0d
# 24    C  3.362421  0.000000 -3.105936  12.01100    #909090
# 25    H  3.444053 -0.884279 -3.742741   1.00794    #ffffff
# 26    H  4.210678  0.000000 -2.417446   1.00794    #ffffff
# 27    C  3.078276 -3.409845  1.562132  12.01100    #909090
# 28    H  2.948217 -2.695167  2.440298   1.00794    #ffffff
# 29    H  3.399300 -4.313795  1.890694   1.00794    #ffffff
# 30    H  3.881149 -2.895298  0.951982   1.00794    #ffffff
# 31    C -3.078276 -3.409845  1.562132  12.01100    #909090
# 32    C -3.362421  0.000000 -3.105936  12.01100    #909090
# 33    C  3.078276  3.409845  1.562132  12.01100    #909090
# 34    C -3.078276  3.409845  1.562132  12.01100    #909090
# 35    H -3.444053  0.884279 -3.742741   1.00794    #ffffff
# 36    H  3.444053  0.884279 -3.742741   1.00794    #ffffff
# 37    H -3.444053 -0.884279 -3.742741   1.00794    #ffffff
# 38    H -4.210678  0.000000 -2.417446   1.00794    #ffffff
# 39    H -2.948217  2.695167  2.440298   1.00794    #ffffff
# 40    H  2.948217  2.695167  2.440298   1.00794    #ffffff
# 41    H -2.948217 -2.695167  2.440298   1.00794    #ffffff
# 42    H -3.399300  4.313795  1.890694   1.00794    #ffffff
# 43    H  3.399300  4.313795  1.890694   1.00794    #ffffff
# 44    H -3.399300 -4.313795  1.890694   1.00794    #ffffff
# 45    H -3.881149  2.895298  0.951982   1.00794    #ffffff
# 46    H  3.881149  2.895298  0.951982   1.00794    #ffffff
# 47    H -3.881149 -2.895298  0.951982   1.00794    #ffffff
# 48    H  0.000000  3.543451 -2.779712   1.00794    #ffffff
# 49    H  1.769272  5.235369  0.747699   1.00794    #ffffff
# 50    H -1.769272  5.235369  0.747699   1.00794    #ffffff
# 51    H  1.769272 -5.235369  0.747699   1.00794    #ffffff
# 52    H -1.769272 -5.235369  0.747699   1.00794    #ffffff
# 53    H  0.000000  0.000000  0.890000   1.00794    #ffffff
# 54    H  0.000000  4.228280 -1.550135   1.00794    #ffffff
# 55    H  0.000000 -3.543451 -2.779712   1.00794    #ffffff
# 56    H  0.000000 -4.228280 -1.550135   1.00794    #ffffff

# %% [markdown]
# If you now look at ``small`` again, you see that it remained unchanged.
# This is in general true for all methods (if not otherwise stated), they return a copy of the original molecule
# and are **sideeffect free**

# %%
small;

# %% [markdown]
# Let's calculate the inertia moments for the three principal axes of inertia (in $u \cdot Å^2$)

# %%
small.inertia()['diag_inertia_tensor']
# Out:
# array([  5397.5575562 ,  11345.21009954,  13596.46749923])

# %% [markdown]
# If you want to know more about the functionality of the ``inertia`` method, just type ``?`` in the beginning or press ``<Shift> + <Tab>`` while typing. ``<Tab>`` completion works of course as well:

# %%
# ?small.inertia()

# %% [markdown]
# # Chemical bonds

# %% [markdown]
# One really important method in the background is ``get_bonds()``. If you ask for the docstring with ``?`` you will see that it is **not sideeffect free** because it creates a lookup variable for performance reasons.

# %%
small.get_bonds(use_valency=False)
# Out:
# Warning: You specified use_valency=False (or used the default)
# and provided a geometry with over saturated atoms.
# This means that bonds are not cut even if their number exceeds the valency.
# If you don't want to see this warning go to settings.py and edit the dictionary.
# Or execute cc.settings.show_warnings['valency'] = False.
# The problematic indices are:
# [3, 7, 18]
# {1: {2, 51},
#  2: {1, 9, 27},
#  3: {6, 55, 56},
#  4: {5, 52},
#  5: {4, 15, 31},
#  6: {3, 7, 8, 9, 15, 16},
#  7: {6, 11, 53},
#  8: {6, 10},
#  9: {2, 6},
#  10: {8, 12, 24},
#  11: {7, 12, 13, 18, 19, 20},
#  12: {10, 11},
#  13: {11, 14},
#  14: {13, 22, 33},
#  15: {5, 6},
#  16: {6, 17},
#  17: {16, 20, 32},
#  18: {11, 48, 54},
#  19: {11, 21},
#  20: {11, 17},
#  21: {19, 23, 34},
#  22: {14, 49},
#  23: {21, 50},
#  24: {10, 25, 26, 36},
#  25: {24},
#  26: {24},
#  27: {2, 28, 29, 30},
#  28: {27},
#  29: {27},
#  30: {27},
#  31: {5, 41, 44, 47},
#  32: {17, 35, 37, 38},
#  33: {14, 40, 43, 46},
#  34: {21, 39, 42, 45},
#  35: {32},
#  36: {24},
#  37: {32},
#  38: {32},
#  39: {34},
#  40: {33},
#  41: {31},
#  42: {34},
#  43: {33},
#  44: {31},
#  45: {34},
#  46: {33},
#  47: {31},
#  48: {18},
#  49: {22},
#  50: {23},
#  51: {1},
#  52: {4},
#  53: {7},
#  54: {18},
#  55: {3},
#  56: {3}}

# %% [markdown]
# Perhaps you want to play a bit with the ``use_valency`` option while viewing at the molecule. If you get annoyed of the warnings just change the settings.

# %%
cc.settings.show_warnings['valency'] = False

# %% [markdown]
# Let's explore the coordinationsphere of the Cr atom with the index 6.

# %%
for i in range(8):
    small.connected_to(6, follow_bonds=i).write('coordinationsphere_' + str(i) + '.xyz')

# %%
# keep a clean directory
# !rm coordinationsphere_?.xyz

# %% [markdown]
# We can also partition the molecule into subsets of the same chemical environment

# %%
small.partition_chem_env()
# Out:
# {('C', frozenset({('C', 1), ('Cr', 1), ('H', 4), ('O', 7)})): {27, 31, 33, 34},
#  ('C', frozenset({('C', 1), ('Cr', 2), ('H', 3), ('O', 11)})): {24, 32},
#  ('C', frozenset({('C', 4), ('Cr', 2), ('H', 7), ('O', 7)})): {2, 5, 14, 21},
#  ('C', frozenset({('C', 6), ('Cr', 2), ('H', 8), ('O', 11)})): {10, 17},
#  ('Cr', frozenset({('C', 10), ('Cr', 1), ('H', 19), ('O', 13)})): {6, 11},
#  ('H', frozenset({('C', 2), ('Cr', 2), ('H', 2), ('O', 2)})): {25,
#   26,
#   35,
#   36,
#   37,
#   38},
#  ('H', frozenset({('C', 4), ('Cr', 2), ('H', 2), ('O', 6)})): {48, 54, 55, 56},
#  ('H', frozenset({('C', 6), ('Cr', 2), ('H', 4), ('O', 11)})): {53},
#  ('H', frozenset({('C', 2), ('Cr', 1), ('H', 3), ('O', 2)})): {28,
#   29,
#   30,
#   39,
#   40,
#   41,
#   42,
#   43,
#   44,
#   45,
#   46,
#   47,
#   49,
#   50,
#   51,
#   52},
#  ('O', frozenset({('C', 2), ('Cr', 1), ('H', 4), ('O', 6)})): {1, 4, 22, 23},
#  ('O', frozenset({('C', 8), ('Cr', 2), ('H', 6), ('O', 12)})): {8, 12, 16, 20},
#  ('O', frozenset({('C', 12), ('Cr', 2), ('H', 5), ('O', 14)})): {7},
#  ('O', frozenset({('C', 8), ('Cr', 2), ('H', 3), ('O', 12)})): {3, 18},
#  ('O', frozenset({('C', 8), ('Cr', 2), ('H', 7), ('O', 12)})): {9, 13, 15, 19}}

# %% [markdown]
# Another task we can easily solve is: making cuts of different geometrical shape, while preserving covalent bonds.

# %%
middle.cutsphere(radius=7, origin=13, preserve_bonds=False).write('sphere.xyz')
middle.cutcuboid(a=11, origin=13, preserve_bonds=False).write('cube.xyz')
middle.cutsphere(radius=7, origin=13, preserve_bonds=True).write('sphere2.xyz')

# %%
# keep a clean directory
# !rm sphere.xyz cube.xyz sphere2.xyz

# %% [markdown]
# You have access to a lot more methods not presented here. Just compare with the documentation.

# %% [markdown]
# # Transformation to internal coordinates

# %%
z_small = small.to_zmat()

# %% [markdown]
# If you look closely at the atoms that were chosen as reference, you can see that it is quite similar to how a chemist would choose them.

# %%
z_small
# Out:
#    atom  bond_with      bond  angle_with       angle  dihedral_with  \
# 7     O        NaN       NaN         NaN         NaN            NaN
# 11   Cr          7  1.952026         NaN         NaN            NaN
# 53    H          7  0.890000          11  119.132614            NaN
# 6    Cr          7  1.952026          11  121.734771             53
# 16    O          6  1.949800           7   90.270495             11
# 8     O          6  1.949800           7   90.270495             11
# 3     O          6  1.951342           7  180.000000             11
# 9     O          6  1.936862           7   86.222347             11
# 15    O          6  1.936862           7   86.222347             11
# 5     C         15  1.304149           6  139.863676              7
# 4     O          5  1.304149          15  113.561691              6
# 31    C          5  1.460789          15  123.219166              6
# 41    H         31  1.139673           5  108.068992             15
# 44    H         31  1.013970           5  116.103706             15
# 47    H         31  1.132098           5  108.508067             15
# 12    O         11  1.949800           7   90.270495             53
# 10    C         12  1.303680          11  138.980553              7
# 24    C         10  1.460790          12  121.477117             11
# 25    H         24  1.092764          10  110.882645             12
# 26    H         24  1.092501          10  110.887878             12
# 36    H         24  1.092764          10  110.882645             12
# 20    O         11  1.949800          12  101.387774              7
# 17    C         20  1.303680          11  138.980553             12
# 32    C         17  1.460790          20  121.477117             11
# 35    H         32  1.092764          17  110.882645             20
# 37    H         32  1.092764          17  110.882645             20
# 38    H         32  1.092501          17  110.887878             20
# 13    O         11  1.936862          12   89.746747             20
# 14    C         13  1.304149          11  139.863676             12
# 33    C         14  1.460789          13  123.219166             11
# 22    O         14  1.304149          13  113.561691             11
# 49    H         22  0.970000          14  106.000000             13
# 19    O         11  1.936862          13   78.948348             12
# 21    C         19  1.304149          11  139.863676             13
# 34    C         21  1.460789          19  123.219166             11
# 23    O         21  1.304149          19  113.561691             11
# 50    H         23  0.970000          21  106.000000             19
# 18    O         11  1.951342          13   93.764988             19
# 48    H         18  0.890000          11  127.750000             13
# 54    H         18  0.890000          11  127.750000             13
# 2     C          9  1.304149           6  139.863676             15
# 1     O          2  1.304149           9  113.561691              6
# 27    C          2  1.460789           9  123.219166              6
# 28    H         27  1.139673           2  108.068992              9
# 29    H         27  1.013970           2  116.103706              9
# 30    H         27  1.132098           2  108.508067              9
# 55    H          3  0.890000           6  127.750000              8
# 56    H          3  0.890000          55  104.499999              6
# 39    H         34  1.139673          21  108.068992             50
# 40    H         33  1.139673          14  108.068992             49
# 45    H         34  1.132098          39  102.192841             21
# 46    H         33  1.132098          40  102.192841             14
# 51    H          1  0.970000           2  106.000000              9
# 52    H          4  0.970000           5  106.000000             15
# 42    H         34  1.013970          45  110.811919             39
# 43    H         33  1.013970          46  110.811919             40
#
#       dihedral
# 7          NaN
# 11         NaN
# 53         NaN
# 6   180.000000
# 16  309.305333
# 8    50.694667
# 3   180.000000
# 9   140.422999
# 15  219.577001
# 5   185.520489
# 4    23.962716
# 31  203.962617
# 41  311.270966
# 44  186.899704
# 47   61.360552
# 12  129.305333
# 10   18.815334
# 24  188.190326
# 25  209.990809
# 26   89.999961
# 36  330.009113
# 20  269.669588
# 17   71.515078
# 32  171.809674
# 35   29.990887
# 37  150.009191
# 38  270.000039
# 13  176.551481
# 14   95.232681
# 33  203.962617
# 22   23.962716
# 49  180.000000
# 19  177.170556
# 21   87.596763
# 34  156.037383
# 23  336.037284
# 50  180.000000
# 18   93.106761
# 48  140.423689
# 54  320.423689
# 2    87.596763
# 1   336.037284
# 27  156.037383
# 28   48.729034
# 29  173.100296
# 30  298.639448
# 55  309.305392
# 56  180.000000
# 39  228.729092
# 40  131.270908
# 45  114.337231
# 46  245.662769
# 51  180.000000
# 52  180.000000
# 42  242.595217
# 43  117.404783

# %% [markdown]
# With internal coordinates it is very easy to modify the angle of fragments. In cartesian coordinates this would involve a lot of trigonometry. So let's get the fragment.

# %%
fragment = middle.get_fragment([(13, 23), (152, 11), (2, 9)])
fragment.write('fragment.xyz')

# %%
# keep a clean directory
# !rm fragment.xyz

# %%
connection = np.array([[11, 152, 5, 63], [23, 11, 152, 13], [9, 11, 23, 152]])

# %%
z_middle = middle.to_zmat(fragment_list=[(fragment, connection)])

# %%
zframe = z_middle.zmat_frame.copy()

# %%
list_of_zmats = [cc.Zmat(zframe)]
for angle in range(80, 150, 5):
    zframe.loc[11, 'angle'] = angle
    new_molecule = cc.Zmat(zframe)
    list_of_zmats.append(new_molecule)

# %%
list_of_cartesians = [zmat.to_xyz() for zmat in list_of_zmats]

# %% [markdown]
# Now have a look at ``benzene_movement.molden``.

# %%
write_molden(list_of_cartesians, 'benzene_movement.molden')

# %%
# keep a clean directory
# !rm benzene_movement.molden

# %% [markdown]
# # Dealing with Linearity

# %% [markdown]
# (Local) linearity is a typical pitfall for conversion to zmatrices and back. The following lines shows that this is no problem for this module.
# Keep in mind that it **does not use** dummy atoms.

# %% [markdown]
# ## Linear molecule

# %%
lmolecule = cc.Cartesian.read_xyz('nasty_linear.xyz')

# %%
lmolecule2 = lmolecule.to_zmat(check_linearity=False).to_xyz()

# %%
write_molden([lmolecule, lmolecule2], 'transformation_linear.molden')

# %% [markdown]
# ## Cube

# %%
cubic = cc.Cartesian.read_xyz('nasty_cube.xyz')

# %%
cubic2 = cubic.to_zmat(check_linearity=True).to_xyz()

# %%
write_molden([cubic, cubic2], 'transformation_cubic.molden')

# %%
# keep a clean directory
# !rm transformation_cubic.molden transformation_linear.molden

# %% [markdown]
# # Customization

# %% [markdown]
# You can safely inherit from the Classes in this module

# %%
class my_tailored_class(cc.xyz_functions.Cartesian):
    def my_number_one_method(self):
        return 1

# %%
molecule = cc.Cartesian.read_xyz('MIL53_small.xyz')
type(molecule)
# Out:
# chemcoord.xyz_functions.Cartesian

# %% [markdown]
# Notice how all old methods from Cartesian return an object of your tailored class

# %%
my_molecule = my_tailored_class.read_xyz('MIL53_small.xyz')
type(my_molecule)
# Out:
# __main__.my_tailored_class

# %%
type(my_molecule.inertia()['transformed_Cartesian'])
# Out:
# __main__.my_tailored_class

# %%
my_molecule.inertia()['transformed_Cartesian'].my_number_one_method()
# Out:
# 1
